# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import skew, kurtosis, shapiro

# %%
import matplotlib as mpl

mpl.rcParams['text.color'] = 'w'
mpl.rcParams['xtick.color'] = 'w'
mpl.rcParams['ytick.color'] = 'w'
mpl.rcParams['axes.labelcolor'] = 'w'
mpl.rcParams['axes.facecolor'] = '#323232'

# %%
# be sure to check OTGLY stock
start_date = "2010-01-01"
end_date = "2020-01-01"
stocks = "AZN BYND FB VTI AAPL PYPL DIS UBER GOOGL"
data = yf.download(stocks, start=start_date, end=end_date, group_by="ticker")
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
data = data.loc[:, pd.IndexSlice[:, 'Adj Close']]
data.columns = data.columns.get_level_values(0)

# %%
return_data = data.pct_change()
return_data.hist(figsize=(20, 20))
plt.show()

# %%
annualized_mean_return = ((1 + return_data.mean()) ** 252) - 1
annualized_return_variance = (return_data.std() * np.sqrt(252)) ** 2 
annualized_mean_return
print("Mu: {}, Variance: {}".format(annualized_mean_return, annualized_return_variance))
# Out:
# Mu: UBER    -0.340336
# VTI      0.147337
# AZN      0.202710
# FB       0.330336
# DIS      0.204722
# BYND     1.009388
# PYPL     0.325329
# GOOGL    0.192259
# AAPL     0.316833
# dtype: float64, Variance: UBER     0.208845
# VTI      0.022525
# AZN      0.050516
# FB       0.130855
# DIS      0.044278
# BYND     1.013046
# PYPL     0.082103
# GOOGL    0.059247
# AAPL     0.066292
# dtype: float64

# %%
# a positive skewness suggests better return
skew(return_data.dropna())
# Out:
# array([-0.28801266, -0.9025377 ,  0.85652799, -0.83484297,  0.80700761,
#         1.16470747,  0.28336995,  1.1335708 , -0.77538897])

# %%
# excess kurtosis = kurtosis + 3
kurtosis(return_data.dropna()) + 3
# Out:
# array([ 4.80544805,  5.40723762,  6.51861845,  5.59725126,  9.25643785,
#        13.65934652,  6.30002447, 14.69291784,  5.17372748])

# %%
# check normal distribution
shapiro(return_data['PYPL'].dropna())
# Out:
# (0.9603368043899536, 5.580969725794047e-17)

# %%
# BYND is not so familiar to you
del return_data['BYND']

# %%
equal_weights = np.full(8, 0.125)

# %%
equal_weighted_return = return_data * equal_weights
equal_weighted_return
# Out:
#                 UBER       VTI       AZN        FB       DIS      PYPL  \
# Date
# 2009-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-04       NaN  0.002084  0.001252       NaN -0.000698       NaN
# 2010-01-05       NaN  0.000480 -0.002531       NaN -0.000312       NaN
# 2010-01-06       NaN  0.000174 -0.000996       NaN -0.000664       NaN
# 2010-01-07       NaN  0.000521  0.001356       NaN  0.000039       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24  0.000453  0.000028 -0.000050 -0.000643  0.000527  0.000092
# 2019-12-26  0.000944  0.000604 -0.000050  0.001627  0.000353  0.001219
# 2019-12-27 -0.002038 -0.000114  0.001479  0.000186  0.000043 -0.000399
# 2019-12-30 -0.001782 -0.000678 -0.001066 -0.002216 -0.001698 -0.001634
# 2019-12-31  0.000000  0.000329 -0.000375  0.000514  0.000748  0.000232
#
#                GOOGL      AAPL
# Date
# 2009-12-31       NaN       NaN
# 2010-01-04  0.001365  0.001946
# 2010-01-05 -0.000550  0.000216
# 2010-01-06 -0.003151 -0.001988
# 2010-01-07 -0.002910 -0.000231
# ...              ...       ...
# 2019-12-24 -0.000574  0.000119
# 2019-12-26  0.001677  0.002480
# 2019-12-27 -0.000718 -0.000047
# 2019-12-30 -0.001378  0.000742
# 2019-12-31 -0.000030  0.000913
#
# [2517 rows x 8 columns]

# %%
# lengths are not equal, kinda meaningless
return_sum = equal_weighted_return.sum(axis=0)
# equal_weighted_return.isna().sum()
return_count = equal_weighted_return.notna().sum()
return_sum.div(return_count)
# Out:
# UBER    -0.000206
# VTI      0.000068
# AZN      0.000092
# FB       0.000142
# DIS      0.000092
# PYPL     0.000140
# GOOGL    0.000087
# AAPL     0.000137
# dtype: float64

# %%
cumulative_stock_return = ((1 + equal_weighted_return).cumprod() - 1)
cumulative_stock_return
# Out:
#                 UBER       VTI       AZN        FB       DIS      PYPL  \
# Date
# 2009-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-04       NaN  0.002084  0.001252       NaN -0.000698       NaN
# 2010-01-05       NaN  0.002565 -0.001283       NaN -0.001009       NaN
# 2010-01-06       NaN  0.002740 -0.002277       NaN -0.001673       NaN
# 2010-01-07       NaN  0.003262 -0.000924       NaN -0.001634       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24 -0.031078  0.184920  0.254207  0.301545  0.258124  0.168594
# 2019-12-26 -0.030163  0.185636  0.254144  0.303663  0.258568  0.170019
# 2019-12-27 -0.032139  0.185501  0.256000  0.303906  0.258622  0.169553
# 2019-12-30 -0.033863  0.184697  0.254661  0.301016  0.256484  0.167642
# 2019-12-31 -0.033863  0.185087  0.254191  0.301684  0.257424  0.167912
#
#                GOOGL      AAPL
# Date
# 2009-12-31       NaN       NaN
# 2010-01-04  0.001365  0.001946
# 2010-01-05  0.000814  0.002162
# 2010-01-06 -0.002340  0.000170
# 2010-01-07 -0.005243 -0.000062
# ...              ...       ...
# 2019-12-24  0.240318  0.397105
# 2019-12-26  0.242399  0.400570
# 2019-12-27  0.241506  0.400504
# 2019-12-30  0.239796  0.401543
# 2019-12-31  0.239759  0.402823
#
# [2517 rows x 8 columns]

# %%
total_return = return_data.iloc[:, 0:9].mul(equal_weights, axis=1).sum(axis=1)
cumulative_total_return = ((1 + total_return).cumprod() - 1)
cumulative_total_return.plot()
plt.show()

# %%
stock_list = [stock for stock in stocks.split()]
company_cap = np.array([])
for item in stock_list:
    try:
        cap = yf.Ticker(item).info['marketCap']
        company_cap = np.append(company_cap, cap)
        print(item, cap)
    except:
        cap = 'None'
        company_cap = np.append(company_cap, cap)
        print(item, cap)
# Out:
# AZN 127823446016
# BYND 7418310656
# FB 611649519616
# VTI None
# AAPL 1401466126336
# PYPL 143605497856
# DIS 251732525056
# UBER 70246539264
# GOOGL 1043223412736

# %%
company_cap
# Out:
# array([], dtype=float64)
